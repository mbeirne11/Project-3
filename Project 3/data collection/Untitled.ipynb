# %%
import pandas as pd

# %%
df1 = pd.read_csv('LanguagePeaceCOL.csv')
df2 = pd.read_html('https://en.wikipedia.org/wiki/List_of_official_languages_by_country_and_territory')[0]

# %%
df2['Official language'].unique()
# Out:
# array(['Abkhaz Russian', 'Persian (Dari) Pashto', 'Albanian',
#        'Arabic Berber', 'Catalan[4]', 'Portuguese', 'English[6]',
#        'None (Spanish has de facto status)', 'Armenian',
#        'Armenian Russian', 'None (English has de facto status)', 'German',
#        'Azerbaijani', 'English', 'Arabic', 'Bengali',
#        'Belarusian Russian', 'Dutch French German', 'French', 'Dzongkha',
#        "Castilian (Spanish) Aymara Araona Baure Bésiro (Chiquitano) Canichana Cavineña Cayubaba Chácobo Chimán Ese Ejja Guaraní Guarasu'we Guarayu Itonama Leco Machajuyai-Kallawaya Machineri Maropa Mojeño-Ignaciano Mojeño-Trinitario Moré Mosetén Movima Pacawara Puquina Quechua Sirionó Tacana Tapieté Toromona Uru-Chipaya Weenhayek Yaminawa Yuki Yuracaré Zamuco",
#        'None (Bosnian, Croatian and Serbian all have de facto status)[15]',
#        'Portuguese[16]', 'Malay', 'Bulgarian', 'French Kirundi English',
#        'Khmer', 'English French', 'English (Federal) French (Federal)',
# ...

# %%
df1
# Out:
#         Country                                           Official  \
# 0       Albania                                           Albanian
# 1       Algeria                                      Arabic,Berber
# 2     Argentina                 None (Spanish has de facto status)
# 3       Armenia                                           Armenian
# 4     Australia                 None (English has de facto status)
# ..          ...                                                ...
# 110  Uzbekistan                                              Uzbek
# 111   Venezuela                   Spanish,Venezuelan Sign Language
# 112     Vietnam                                         Vietnamese
# 113       Yemen                                             Arabic
# 114    Zimbabwe  Chewa,Chibarwe,English,Kalanga,Khoisan,Nambya,...
#
#     2023[4] Rank    COL
# 0            40=   84.0
# 1             96  126.0
# 2             54  118.0
# 3             66   72.0
# 4             22   11.0
# ...

# %%
languages = df1['Official'].unique()

# %%
all_languages = []
for row in languages:
    new_list = row.split(',')
    for lang in new_list:
        if (lang in all_languages) == False:
            all_languages.append(lang)

# %%
all_languages
# Out:
# ['Albanian',
#  'Arabic',
#  'Berber',
#  'None (Spanish has de facto status)',
#  'Armenian',
#  'None (English has de facto status)',
#  'German',
#  'Azerbaijani',
#  'Bengali',
#  'Belarusian',
#  'Russian',
#  'Dutch',
#  'French',
#  'Castilian (Spanish)',
#  'Aymara',
#  'Araona',
#  'Baure',
#  'Bésiro (Chiquitano)',
#  'Canichana',
#  'Cavineño',
#  'Cayubaba',
#  'Chácobo',
#  'Chimán',
#  'Ese Ejja',
#  'Guaraní',
#  "Guarasu'we",
#  'Guarayu',
#  'Itonama',
#  'Leco',
#  'Machajuyai-Kallawaya',
#  'Machineri',
#  'Maropa',
#  'Mojeño-Ignaciano',
#  'Mojeño-Trinitario',
#  'Moré',
#  'Mosetén',
#  'Movima',
#  'Pacawara',
#  'Puquina',
#  'Quechua',
#  'Sirionó',
#  'Tacana',
#  'Tapieté',
#  'Toromona',
#  'Uru-Chipaya',
#  'Weenhayek',
#  'Yaminawa',
#  'Yuki',
#  'Yuracaré',
#  'Zamuco',
#  'English',
#  'Portuguese[16]',
#  'Bulgarian',
#  'Khmer',
#  'English (Federal)',
#  'French (Federal)',
#  'Chilean Spanish',
#  'Standard Chinese',
#  'Spanish',
#  'Croatian',
# ...
